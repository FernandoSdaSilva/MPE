# %% [markdown]
# # Dados

# %% [markdown]
# ## Dicionário das variáveis
#
# * [Preço de venda imóveis - Índice FipeZap Porto Alegre Residencial Venda 3Dorm](https://www.fipe.org.br/pt-br/indices/fipezap/#indice-mensal)
#     * Fonte: FIPE
#     * Periodicidade original: mensal
#     * Período amostra: 07/12 - 01/22
#
#
# *  [Taxa de aluguel (rental yield) BRASIL 3 Dormitórios](https://www.fipe.org.br/pt-br/indices/fipezap/#indice-mensal)
#     * Preço de locação/ Preço venda
#     * Fonte: FIPE
#     * Periodicidade original: mensal // Série histórica POA começa a partir de 2014
#
#
# <font color='darkgreen'> Objetivo: testar se oscilações nos rendimentos de investimentos imobiliários por meio de aluguéis de imóveis do grupo selecionado impactam no preço agregado destes ativos. </font>
#
#
# <font color='purple'>Hipótese: em caso de uma elevação significativa da taxa básica de juros, caso não haja condições de repasses nos aluguéis, investidores que buscam rendimentos de aluguel podem migrar para outras opções conservadoras e com maior liquidez, como NTN-Bs ou CBDs, aumentando a oferta de imóveis num curto espaço de tempo (tendência de queda nos preços). Por outro lado, uma queda "exagerada" no valor dos imóveis aumentaria o retorno (yield %), o que poderia levar ao aumento da demanda destes ativos por investidores.</font>
#
# Yield = Aluguel/Preço do Imovel -> se o valor dos imóveis tiver uma queda brusca, o yield do aluguel aumentaria, o que poderia mais do que compensar o efeito da elevação da taxa de juros.
#
#
# *  [Inflação ao consumidor](https://www3.bcb.gov.br/sgspub/localizarseries/localizarSeries.do?method=prepararTelaLocalizarSeries)
#      * IPCA Porto Alegre
#      * Fonte: IBGE/ site BACEN
#      * Periodicidade original: mensal
#
#  Economia Regional > Sul > RS > Setor Real
#
#
# <font color='darkgreen'> Objetivo: Analisar o impacto do aumento agregado do nível de preços ao consumidor (corrosão do poder de compra geral) sobre o preço de imóveis. </font>
#
#
# <font color='purple'>Hipótese: Do lado da demanda, a corrosão do poder de compra deve diminuir a demanda agregada por imóveis, especialmente num mercado altamente dependente de crédito para aquisição. Do lado da oferta, será que haverá poder de repasse proporcional ao da inflação ponderada, especialmente quando a inflação dos custos de produção (CUB, SINAPI) forem elevados abruptamente? Isso ocorreu no período recente desde o início da pandemia (variação de CUB da ordem de 1/3 em 2 anos, com alguns materiais subindo +200%) e suspeito que o preço dos imóveis não teve repasse proporcional. Ou seja, acredito que haverá impacto positivo no preço dos imóveis, mas não na mesma magnitude do que a inflação dos custos de produção.</font>
#
# Obs: como estamos tratando de imóveis "médio-alto padrão", talvez essa parcela da população tenha sua renda menos afetada por choques inflacionários, uma vez que pode diversificar seu portfolio de investimentos em estratégias como IPCA+ ou outras classes de ativos que protegem o poder de compra.
#
#
# *  [Taxa de básica de juros](https://www3.bcb.gov.br/sgspub/localizarseries/localizarSeries.do?method=prepararTelaLocalizarSeries)
#      * SELIC - Meta definida pelo Copom %a.a.
#      * Fonte: BACEN
#      * Periodicidade original: diária
#      * Critério de conversão:  Gretl -> Compactar dados -> início de período
#
# Indic Monetários > Política Monetária > Taxa Selic
#
#
# <font color='darkgreen'> Objetivo: Aferir o impacto da política monetária no preço de imóveis selecionados.
#  </font>
#
#
# <font color='purple'>Hipótese: alta na taxa básica de juros deve encarecer financiamentos imobiliários, tanto para produção quanto para aquisição e, assim, refletir numa redução na demanda agregada. Se não houver retração nos preços, possivelmente haverá, pelo menos, uma redução de processos inflacionários.
# </font>
#
#
# *  [Custo de crédito imobiliário
# ](https://www3.bcb.gov.br/sgspub/localizarseries/localizarSeries.do?method=prepararTelaLocalizarSeries
# )
#      * Taxa média mensal de juros - Pessoas físicas - Financiamento imobiliário total %a.m.
#      * Fonte: BACEN
#      * Periodicidade original: mensal
#
#
# Indicadores de Crédito > Tx de juros % a.m. > Tx de juros com recursos direcionados
#
#
# <font color='darkgreen'> Objetivo: Em um mercado altamente dependente de crédito, tanto para produção quanto para aquisição, a taxa de juros corrente no setor deve impactar de modo significante nos preços agregados. A questão é: quanto tempo leva para fazer efeito. Se assemelha a SELIC, que deve impactar no custo do crédito imobiliário. A diferença aqui é que analisaremos a taxa de juros específica para contratação de crédito imobiliário e não a taxa básica utilizada para política monetária.
#
#  </font>
#
#
# <font color='purple'>Hipótese: Deve apresentar correlação inversa (negativa). Uma alta na taxa mensal de juros para financiamento imobiliário deve, se não tiver força suficiente para resultar em queda efetiva, pelo menos, frear a alta de preços no setor. De modo análogo, taxas de juro mais baixas devem impulsionar a demanda, de modo a pressionar os preços positivamente. No entanto, como este é um segmento altamente intensivo na utilização de crédito também para produção, pode ser que o aumento na oferta compense o aumento na demanda (resposta ao impulso deve ser interessante).
#
# </font>
#
# *  [Taxa de crescimento do PIB
# ](https://dee.rs.gov.br/pib-trimestral
# )
#      * PIB RS Trimestre contra trimestre imediatamente anterior (em %)
#      * Fonte: DEE RS
#      * Periodicidade original: variação trimestral (dados até 2021).
#
#
# *  [IBCR-RS](https://www3.bcb.gov.br/sgspub/consultarvalores/telaCvsSelecionarSeries.paint)
#      * Proxy do PIB do RS
#      * Fonte: BACEN
#      * Periodicidade original: mensal.
#
#
# * [Custos de construção](https://www.ibge.gov.br/estatisticas/economicas/precos-e-custos/9270-sistema-nacional-de-pesquisa-de-custos-e-indices-da-construcao-civil.html?t=series-historicas)
#      * SINAPI RS (variação % a.m.)
#      * Fonte: IBGE
#      * Periodicidade original: mensal. <br><br>
#
# *  [Custos de construção
# ](http://www.cbicdados.com.br/menu/custo-da-construcao/cub-medio-brasil-custo-unitario-basico-de-construcao-por-m2)
#      * CUB RS Global - variação % a.m.
#      * Fonte: CBIC Dados (SINDUSCON-RS)
#      * Periodicidade original: mensal.

# %% [markdown]
# ### <font color='chocolate'>rpy2 is an interface to R running embedded in a Python process </font>

# %%
# !pip install rpy2

# %%
import rpy2

# %%
rpy2.__path__
# Out:
# ['C:\\Users\\Cristina Tessari\\anaconda3\\lib\\site-packages\\rpy2']

# %%
# %load_ext rpy2.ipython
# Out:
# C:\Users\Cristina Tessari\anaconda3\lib\site-packages\rpy2\robjects\packages.py:366: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %% [markdown]
# # 1. Loading packages and data

# %%
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from datetime import datetime

from tqdm.notebook import tqdm

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('display.max_columns', None)

# %%
# Import modules
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Get the current working directory
cwd = os.getcwd()

# Print the current working directory
print("Current working directory: {0}".format(cwd))

# Print the type of the returned object
print("os.getcwd() returns an object of type: {0}".format(type(cwd)))
# Out:
# Current working directory: C:\Users\Cristina Tessari
# os.getcwd() returns an object of type: <class 'str'>

# %%
print("Current working directory: {0}".format(os.getcwd()))

# Change the current working directory
# os.chdir('')

# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: C:\Users\Cristina Tessari
# Current working directory: C:\Users\Cristina Tessari

# %% [markdown]
# Importing panel data and show head, remove index column

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FernandoSdaSilva/MPE/main/Tabela_mensal_final.csv?token=GHSAT0AAAAAABS7KUW3FF4JKK2FUSNBX3FYYSDGUQQ', sep=',')

#retirar coluna Data
#df = df.drop('Data', 1)
#df.head()
display(df)
# Out:
#          Data  FipeZap_POA_3Dorm  Rent_Yield_Br  IPCA_POA  SINAPI_RS  \
# 0    07/01/12           0.909503           0.44      0.60       0.15
# 1    08/01/12           1.912509           0.43      0.48       0.44
# 2    09/01/12           0.626959           0.43      0.58       0.48
# 3    10/01/12           0.589933           0.43      0.50       0.02
# 4    11/01/12           0.883299           0.43      0.41       0.05
# 5    12/01/12           1.368436           0.43      0.62       0.13
# 6    01/01/13           1.335912           0.43      0.87       0.31
# 7    02/01/13           1.116019           0.43      0.35       1.43
# 8    03/01/13           0.911980           0.43      0.46       1.05
# 9    04/01/13           0.479856           0.42      0.32       0.03
# 10   05/01/13           0.204144           0.42      0.50      -4.95
# 11   06/01/13           0.300275           0.42      0.17       9.88
# 12   07/01/13           0.643665           0.41      0.10      -5.52
# ...

# %% [markdown]
# # 2. Checking the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Data                111 non-null    object
#  1   FipeZap_POA_3Dorm   111 non-null    float64
#  2   Rent_Yield_Br       111 non-null    float64
#  3   IPCA_POA            111 non-null    float64
#  4   SINAPI_RS           111 non-null    float64
#  5   Tx_financ_imob      111 non-null    float64
#  6   CUB_RS_varmens      111 non-null    float64
#  7   PIB_RS_vartrimestr  111 non-null    float64
#  8   Tx_desocup_RS       111 non-null    float64
#  9   SELIC_aa            111 non-null    float64
#  10  IBCR_RS             111 non-null    float64
#  11  Tx_desocup_BR       111 non-null    float64
# dtypes: float64(11), object(1)
# memory usage: 10.5+ KB

# %% [markdown]
# Information about dataframe shows 12 columns, 111 rows, Dtype float64 = 11.

# %%
df.shape
# Out:
# (111, 12)

# %% [markdown]
# Another overview over rows = 111, columns = 12.

# %% [raw]
# df.values

# %% [markdown]
# outputs a two-dimensional numpy array of the values from panel data

# %%
df.columns
# Out:
# Index(['Data', 'FipeZap_POA_3Dorm', 'Rent_Yield_Br', 'IPCA_POA', 'SINAPI_RS',
#        'Tx_financ_imob', 'CUB_RS_varmens', 'PIB_RS_vartrimestr',
#        'Tx_desocup_RS', 'SELIC_aa', 'IBCR_RS', 'Tx_desocup_BR'],
#       dtype='object')

# %% [markdown]
# Output are column names of dataframe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=111, step=1)

# %% [markdown]
# # 3. Data manupulation / Preprocessing

# %% [markdown]
# __3.1 Changing the categorical columns to numerical with pd.to_numeric__

# %% [markdown]
# It was not necessary.

# %% [markdown]
# __3.2 Setting column obs to datetime format__

# %%
df['Data'] = pd.to_datetime(df['Data'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Data                111 non-null    datetime64[ns]
#  1   FipeZap_POA_3Dorm   111 non-null    float64
#  2   Rent_Yield_Br       111 non-null    float64
#  3   IPCA_POA            111 non-null    float64
#  4   SINAPI_RS           111 non-null    float64
#  5   Tx_financ_imob      111 non-null    float64
#  6   CUB_RS_varmens      111 non-null    float64
#  7   PIB_RS_vartrimestr  111 non-null    float64
#  8   Tx_desocup_RS       111 non-null    float64
#  9   SELIC_aa            111 non-null    float64
#  10  IBCR_RS             111 non-null    float64
#  11  Tx_desocup_BR       111 non-null    float64
# dtypes: datetime64[ns](1), float64(11)
# memory usage: 10.5 KB

# %% [markdown]
# __3.3 Dealing with the NAN Values__

# %% [markdown]
# __Checking for NaN Values__

# %%
nulls = pd.DataFrame(df.isna().sum()/len(df))
nulls= nulls.reset_index()
nulls.columns = ['column_name', 'Percentage Null Values']
nulls.sort_values(by='Percentage Null Values', ascending = False)
# Out:
#            column_name  Percentage Null Values
# 0                 Data                     0.0
# 1    FipeZap_POA_3Dorm                     0.0
# 2        Rent_Yield_Br                     0.0
# 3             IPCA_POA                     0.0
# 4            SINAPI_RS                     0.0
# 5       Tx_financ_imob                     0.0
# 6       CUB_RS_varmens                     0.0
# 7   PIB_RS_vartrimestr                     0.0
# 8        Tx_desocup_RS                     0.0
# 9             SELIC_aa                     0.0
# 10             IBCR_RS                     0.0
# 11       Tx_desocup_BR                     0.0

# %% [markdown]
# __List the columns with missing values__ \
# __Create histograms showing the distributions cols_with_missing__

# %%
# cols_with_missing = ['PIB', 'AG001A_Pop_Total_Agua_Anterior', 'ES001A_Pop_Total_Esgoto_Anterio']
# df[cols_with_missing].hist()

# %% [markdown]
# # 4. EDA: Data explained by descriptive statistics

# %% [markdown]
# Exploratory Data Analysis (EDA) is an approach to data analysis for summarizing and visualizing the important characteristics of the data. EDA can be considered as a free assumption, normally carried in the data analytics behavior. It is also known as visual analytics or descriptive statistics. It is the practice of observing, and exploring data, before you emphasizing some hypotheses, fitting predictors, and other more intention to the inferential statistics. It typically includes the computation of simple summary statistics that capture some property of interest in the data and visualization.
#
# We are looking to understand what variables you have, how many records the data set contains, how many missing values, what is the variable structure, what are the variable relationships, and more. In this section we perform a basic EDA.
#
#    * How to explore: with summary-statistics, or visually?
#    * How many variables analyzed simultaneously: univariate, bivariate, or multivariate?
#    * What type of variable: categorical or continuous?

# %%
df.describe()
# Out:
#        FipeZap_POA_3Dorm  Rent_Yield_Br    IPCA_POA   SINAPI_RS  \
# count         111.000000     111.000000  111.000000  111.000000
# mean            0.316551       0.361622    0.504234    0.577027
# std             0.619918       0.031667    0.445335    1.423758
# min            -1.815217       0.330000   -0.440000   -5.520000
# 25%            -0.018340       0.335000    0.190000    0.120000
# 50%             0.281311       0.350000    0.480000    0.320000
# 75%             0.650488       0.380000    0.750000    0.650000
# max             1.912509       0.440000    1.850000    9.880000
#
#        Tx_financ_imob  CUB_RS_varmens  PIB_RS_vartrimestr  Tx_desocup_RS  \
# count      111.000000      111.000000          111.000000     111.000000
# mean         0.690541        0.713604            0.411223       7.335135
# std          0.099989        0.949552            4.526202       1.740410
# min          0.540000       -0.360000          -15.388122       4.400000
# ...

# %%
# %%R -i df
#
# library(tidyverse)
# quan <- df %>%
# select_if(is.numeric)                              # select only numeric columns
# names(quan)                                        # check the names of Quantitave variables
# Out:
# C:\Users\Cristina Tessari\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2187: PytzUsageWarning: The zone attribute is specific to pytz's interface; please migrate to a new time zone provider. For more details on how to do so, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
# R[write to console]: -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# R[write to console]: v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.6     v dplyr   1.0.7
# v tidyr   1.1.4     v stringr 1.4.0
# v readr   2.1.1     v forcats 0.5.1
#
# R[write to console]: -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#  [1] "FipeZap_POA_3Dorm"  "Rent_Yield_Br"      "IPCA_POA"
# ...

# %%
# %%R -i df
#
# summary(quan)                                      # basic summary statistics in one function
# Out:
# C:\Users\Cristina Tessari\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2187: PytzUsageWarning: The zone attribute is specific to pytz's interface; please migrate to a new time zone provider. For more details on how to do so, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#  FipeZap_POA_3Dorm  Rent_Yield_Br       IPCA_POA         SINAPI_RS
#  Min.   :-1.81522   Min.   :0.3300   Min.   :-0.4400   Min.   :-5.520
#  1st Qu.:-0.01834   1st Qu.:0.3350   1st Qu.: 0.1900   1st Qu.: 0.120
#  Median : 0.28131   Median :0.3500   Median : 0.4800   Median : 0.320
#  Mean   : 0.31655   Mean   :0.3616   Mean   : 0.5042   Mean   : 0.577
#  3rd Qu.: 0.65049   3rd Qu.:0.3800   3rd Qu.: 0.7500   3rd Qu.: 0.650
#  Max.   : 1.91251   Max.   :0.4400   Max.   : 1.8500   Max.   : 9.880
#  Tx_financ_imob   CUB_RS_varmens    PIB_RS_vartrimestr  Tx_desocup_RS
# ...

# %% [markdown]
# ##### 4.2 Correlation Matrix

# %%
imv_corr = df.corr()

display(imv_corr)
# Out:
#                     FipeZap_POA_3Dorm  Rent_Yield_Br  IPCA_POA  SINAPI_RS  \
# FipeZap_POA_3Dorm            1.000000       0.444629  0.071245  -0.001302
# Rent_Yield_Br                0.444629       1.000000  0.126050  -0.045300
# IPCA_POA                     0.071245       0.126050  1.000000   0.127264
# SINAPI_RS                   -0.001302      -0.045300  0.127264   1.000000
# Tx_financ_imob               0.013846      -0.103064  0.061808  -0.063132
# CUB_RS_varmens               0.082803       0.058063  0.182754   0.372835
# PIB_RS_vartrimestr           0.157516       0.126723  0.054639   0.038407
# Tx_desocup_RS               -0.297037      -0.820672 -0.171710   0.092404
# SELIC_aa                     0.031844       0.012215  0.082326  -0.090380
# IBCR_RS                     -0.114759       0.119787  0.192982  -0.008648
# Tx_desocup_BR               -0.286791      -0.788377 -0.154106   0.121080
#
#                     Tx_financ_imob  CUB_RS_varmens  PIB_RS_vartrimestr  \
# ...

# %%
from scipy.stats import pearsonr
corr,p_val = pearsonr(df['Tx_desocup_RS'], df['Tx_desocup_BR'])
print('Pearson correlation: %.3f;' % corr)
print('O p-valor é: %.3f.' % p_val)
# Out:
# Pearson correlation: 0.950;
# O p-valor é: 0.000.

# %%
df_imv = df.drop(['PIB_RS_vartrimestr', 'Tx_desocup_RS'], 1)
df_imv
# Out:
# C:\Users\CRISTI~1\AppData\Local\Temp/ipykernel_16516/2938800178.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_imv = df.drop(['PIB_RS_vartrimestr', 'Tx_desocup_RS'], 1)
#           Data  FipeZap_POA_3Dorm  Rent_Yield_Br  IPCA_POA  SINAPI_RS  \
# 0   2012-07-01           0.909503           0.44      0.60       0.15
# 1   2012-08-01           1.912509           0.43      0.48       0.44
# 2   2012-09-01           0.626959           0.43      0.58       0.48
# 3   2012-10-01           0.589933           0.43      0.50       0.02
# 4   2012-11-01           0.883299           0.43      0.41       0.05
# 5   2012-12-01           1.368436           0.43      0.62       0.13
# 6   2013-01-01           1.335912           0.43      0.87       0.31
# 7   2013-02-01           1.116019           0.43      0.35       1.43
# 8   2013-03-01           0.911980           0.43      0.46       1.05
# ...

# %%
imv_corr = df_imv.corr()

# %%
imv_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_9a206_row0_col0, #T_9a206_row1_col1, #T_9a206_row2_col2, #T_9a206_row3_col3, #T_9a206_row4_col4, #T_9a206_row5_col5, #T_9a206_row6_col6, #T_9a206_row7_col7, #T_9a206_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9a206_row0_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_9a206_row0_col2, #T_9a206_row8_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_9a206_row0_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_9a206_row0_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_9a206_row0_col5, #T_9a206_row3_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_9a206_row0_col6, #T_9a206_row2_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_9a206_row0_col7, #T_9a206_row1_col8, #T_9a206_row6_col3, #T_9a206_row6_col5, #T_9a206_row8_col0, #T_9a206_row8_col1, #T_9a206_row8_col2, #T_9a206_row8_col4, #T_9a206_row8_col6 {
# ...

# %% [markdown]
# * Using Seaborn <font color='red'>heatmap </font> <font color='brown1'>(Mapa de Calor)</font>

# %%
imv_corr = matrix = np.triu(df_imv.corr())
sns.heatmap(df_imv.corr(), annot=True, mask=matrix, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 4.3 EDA: Plotting and interpretating the results of time series analysis

# %%
df_imv2 = df_imv.drop(['Data'], 1)

df_imv2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FipeZap_POA_3Dorm  111 non-null    float64
#  1   Rent_Yield_Br      111 non-null    float64
#  2   IPCA_POA           111 non-null    float64
#  3   SINAPI_RS          111 non-null    float64
#  4   Tx_financ_imob     111 non-null    float64
#  5   CUB_RS_varmens     111 non-null    float64
#  6   SELIC_aa           111 non-null    float64
#  7   IBCR_RS            111 non-null    float64
#  8   Tx_desocup_BR      111 non-null    float64
# dtypes: float64(9)
# memory usage: 7.9 KB
# C:\Users\CRISTI~1\AppData\Local\Temp/ipykernel_16516/3781540270.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_imv2 = df_imv.drop(['Data'], 1)

# %%
df_imv.plot(x = 'Data',subplots=True, layout=(3,3),  figsize=(20,12), sharex = True)
# Out:
# array([[<AxesSubplot:xlabel='Data'>, <AxesSubplot:xlabel='Data'>,
#         <AxesSubplot:xlabel='Data'>],
#        [<AxesSubplot:xlabel='Data'>, <AxesSubplot:xlabel='Data'>,
#         <AxesSubplot:xlabel='Data'>],
#        [<AxesSubplot:xlabel='Data'>, <AxesSubplot:xlabel='Data'>,
#         <AxesSubplot:xlabel='Data'>]], dtype=object)

# %% [markdown]
# FipeZap_POA_3Dorm  111 non-null    float64
#  1   Rent_Yield_Br      111 non-null    float64
#  2   IPCA_POA           111 non-null    float64
#  3   SINAPI_RS          111 non-null    float64
#  4   Tx_financ_imob     111 non-null    float64
#  5   CUB_RS_varmens     111 non-null    float64
#  6   SELIC_aa           111 non-null    float64
#  7   IBCR_RS            111 non-null    float64
#  8   Tx_desocup_BR

# %%
import statsmodels.tsa.stattools as stattools

    
# Import Data

x = df_imv2['FipeZap_POA_3Dorm']
y = df_imv2['Rent_Yield_Br']

# Compute Cross Correlations
ccs = stattools.ccf(x, y)[:100]
nlags = len(ccs)

# Compute the Significance level
# ref: https://stats.stackexchange.com/questions/3115/cross-correlation-significance-in-r/3128#3128
conf_level = 2 / np.sqrt(nlags)

# Draw Plot
plt.figure(figsize=(12,7), dpi= 80)

plt.hlines(0, xmin=0, xmax=100, color='gray')  # 0 axis
plt.hlines(conf_level, xmin=0, xmax=100, color='gray')
plt.hlines(-conf_level, xmin=0, xmax=100, color='gray')

plt.bar(x=np.arange(len(ccs)), height=ccs, width=.3)

# Decoration
plt.title('$Cross\; Correlation\; Plot:\; FipeZap.POA.3Dorm\; vs\; Rent.Yield.Br$', fontsize=22)
plt.xlim(0,len(ccs))
plt.show()

# %% [markdown]
# ## Joy Plot
#
# Joy Plot allows the density curves of different groups to overlap, it is a great way to visualize the distribution of a larger number of groups in relation to each other. It looks pleasing to the eye and conveys just the right information clearly.
#
# ## CCF Plot
#
# ## Density Plot
#
# Density plots are a commonly used tool visualise the distribution of a continuous variable. By grouping them by the ‘response’ variable, you can inspect the relationship between the X and the Y.
#
# ## Slope Chart
#
# Slope chart is most suitable for comparing the ‘Before’ and ‘After’ positions
#
# ## Pairwise Plot
#
# Pairwise plot is a favorite in exploratory analysis to understand the relationship between all possible pairs of numeric variables. It is a must have tool for bivariate analysis.

# %% [markdown]
# __Boxplots__
#
# Box plots are a great way to visualize the distribution, keeping the median, 25th, 75th quartiles and the outliers in mind.

# %%
# Import libraries
#import matplotlib.pyplot as plt
#import numpy as np
 
data_pop = [san_df['Pop_Total'], san_df['AG001_Pop_Total_Agua'],san_df['ES001_Pop_Total_Esgoto']]
 
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
## add patch_artist=True option to ax.boxplot() 
## to get fill color
# Creating plot
bp = ax.boxplot(data_pop, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='orange', linewidth=2)
    # change fill color
    box.set( facecolor = 'white' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='orange', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='orange', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='black', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5)
    
## Custom x-axis labels
ax.set_xticklabels(['Pop_Total', 'Pop_Total_Agua', 'Pop_Total_Esgoto'])


# show plot
plt.show()

# %%
data_rod = [san_df['FN001_ROD_Total'], san_df['FN002_ROD_Agua'],san_df['FN003_ROD_Esgoto']]
 
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
## add patch_artist=True option to ax.boxplot() 
## to get fill color
# Creating plot
bp = ax.boxplot(data_rod, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='orange', linewidth=2)
    # change fill color
    box.set( facecolor = 'white' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='orange', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='orange', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='black', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5)
    
## Custom x-axis labels
ax.set_xticklabels(['ROD_Total', 'ROD_Agua', 'ROD_Esgoto'])


# show plot
plt.show()

# %% [markdown]
# * Esgoto foi bem menos variável no período (se mede pelo tamanho do box).

# %%
data_invest = [san_df['FN023_Invest_Agua_Prestador'], san_df['FN024_Invest_Esgoto_Prestador']]
 
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
## add patch_artist=True option to ax.boxplot() 
## to get fill color
# Creating plot
bp = ax.boxplot(data_invest, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='orange', linewidth=2)
    # change fill color
    box.set( facecolor = 'white' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='orange', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='orange', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='black', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5)
    
## Custom x-axis labels
ax.set_xticklabels(['Invest_Agua_Prestador', 'Invest_Esgoto_Prestador'])


# show plot
plt.show()

# %% [markdown]
# ##### 4.4 Scatterplot Matrix

# %%
sns.pairplot(san_df, diag_kind="kde", corner=True)

# %%
#If you prefer a smaller plot, use less variables. For instance, if you only want Pop Total,
#Pop Total Agua and Pop Total Esgoto

g = sns.pairplot(san_df, vars=['Pop_Total', 'AG001_Pop_Total_Agua', 'ES001_Pop_Total_Esgoto'], corner = True)


# or g = sns.pairplot(san_df, xvars=['Pop_Total', 'AG001_Pop_Total_Agua', 'ES001_Pop_Total_Esgoto'],\
#                             yvars= ['Ano', 'PIB'])
# diferentes x e y

# %%
# %%R -i san_df
#
# pairs(san_df[,2:4], pch = 19, lower.panel = NULL)

# %%
# %%R -i san_df
#
# pairs(san_df[,5:7], pch = 19, lower.panel = NULL)

# %%
# %%R -i san_df
#
# pairs(san_df[,8:9], pch = 19, lower.panel = NULL)

# %% [markdown]
# * Visualmente podemos ver que a associação/correlação neste banco de dados é forte.

# %% [markdown]
# ### <i>Obs </i>: A correlação medida acima é a de Pearson. Esta métrica só é adequada para medir uma associação linear entre as variáveis. Como possibilidade poderíamos utilizar os coeficientes de correlação de postos (não-paramétricos) de Spearman ou Kendall's tau.

# %% [markdown]
# # 5. Inferential statistics

# %% [markdown]
# ### (Some possible) Nonparametric tests
#
# Three sorts of nonparametric test are available here: for a difference between groups, for randomness, and for (rank) correlation.
#
# #### Difference tests
#
# We can carry out a nonparametric test for a difference between two populations or groups.
#
# • Sign test: This test is based on the fact that if two samples, x and y, are drawn randomly from the same distribution, the probability that xi > yi, for each observation i, should equal 0.5. The test statistic is w, the number of observations for which xi > yi. Under the null hypothesis this follows the Binomial distribution with parameters (n, 0.5), where n is the number of observations.
#
# • Wilcoxon rank-sum test. This test proceeds by ranking the observations from both samples jointly, from smallest to largest, then finding the sum of the ranks of the observations from one of the samples. The two samples do not have to be of the same size, and if they differ the smaller sample is used in calculating the rank-sum. Under the null hypothesis that the samples are drawn from populations with the same median, the probability distribution of the rank-sum can be computed for any given sample sizes; and for reasonably large samples a close Normal approximation exists.
#
# • Wilcoxon signed-rank test. This is designed for matched data pairs such as, for example, the values of a variable for a sample of individuals before and after some treatment. The test proceeds by finding the differences between the paired observations, xi – yi, ranking these differences by absolute value, then assigning to each pair a signed rank, the sign agreeing with the sign of the difference. One then calculates W+, the sum of the positive signed ranks. As with the rank-sum test, this statistic has a well-defined distribution under the null that the median difference is zero, which converges to the Normal for samples of reasonable size.
#
# ### Obs: Não foi feito.

# %% [markdown]
# #### Correlation
#
#  Spearman's rank correlation rho and Kendall's rank correlation tau.
#
#  * No Python utilize
#
# #calculate spearman's correlation
# coef, p = spearmanr(data1, data2)
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html
#
# #calculate kendall's correlation
# coef, p = kendalltau(data1, data2)
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kendalltau.html
#
# onde p representa o p-value do teste (a nula é de que a correlação é igual a zero).
#
# Para exemplificar, eu vou testar com Rod_Esgoto e Invest_Esgoto (menor correlação linear encontrada = 0.37).

# %%
from scipy.stats import spearmanr

corr, p_value = spearmanr(san_df['FN003_ROD_Esgoto'], san_df['FN024_Invest_Esgoto_Prestador'])

print('corr = %.4f.' % corr)
print('p-value = %.4f.' % p_value)
# Out:
# corr = 0.7593.
# p-value = 0.0000.

# %%
from scipy.stats import kendalltau

tau, p_tau = kendalltau(san_df['FN003_ROD_Esgoto'], san_df['FN024_Invest_Esgoto_Prestador'])

print('tau = %.4f.' % tau)
print('p_tau = %.4f.' % p_tau)
# Out:
# tau = 0.5385.
# p_tau = 0.0001.

# %% [markdown]
# * Note que os p-values são quase zero.
#
# #### Obs: Não devemos/podemos fazer testes paramétricos com este tamanho de amostra.

# %% [markdown]
# # 6. Autocorrelation

# %% [markdown]
# ##### 6.1 Time Series Plots

# %%
l_san_df = np.log(san_df)
l_san_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Ano                            26 non-null     float64
#  1   Pop_Total                      26 non-null     float64
#  2   AG001_Pop_Total_Agua           26 non-null     float64
#  3   ES001_Pop_Total_Esgoto         26 non-null     float64
#  4   FN001_ROD_Total                26 non-null     float64
#  5   FN002_ROD_Agua                 26 non-null     float64
#  6   FN003_ROD_Esgoto               26 non-null     float64
#  7   FN023_Invest_Agua_Prestador    26 non-null     float64
#  8   FN024_Invest_Esgoto_Prestador  26 non-null     float64
#  9   PIB                            26 non-null     float64
# dtypes: float64(10)
# memory usage: 2.2 KB

# %%
l_san_df.plot(x='Ano', kind='line', title='Sanitation evolution over time')
rcParams['figure.figsize'] = 15, 4

ax = plt.subplot(111)

# Increase height by 200%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height*3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ### Todas as variáveis acima estão em log.
#
# ### Note que muitas parecem cointegrar.

# %% [markdown]
# #### 6.1.1 STL or Time Series Decomposition Plot (Seasonal, Trend and Loess)
#
# Time series decomposition plot shows the break down of the time series into trend, seasonal and residual components.

# %%
# import required packages, prepare the graphics environment, and prepare the data.

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()
sns.set_style("darkgrid")

plt.rc("figure", figsize=(16, 12))
plt.rc("font", size=13)

# %%
# !pip install statsmodels==v0.13.2
# Out:
# ...
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# ...

# %%
from statsmodels.tsa.seasonal import STL

stl = STL(l_san_df["Pop_Total"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %% [markdown]
# #### População Total tem uma tendência forte.

# %%
stl = STL(l_san_df["AG001_Pop_Total_Agua"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %%
stl = STL(l_san_df["ES001_Pop_Total_Esgoto"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %%
stl = STL(l_san_df["FN001_ROD_Total"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %%
stl = STL(l_san_df["FN002_ROD_Agua"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %%
stl = STL(l_san_df["FN003_ROD_Esgoto"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %%
stl = STL(l_san_df["FN023_Invest_Agua_Prestador"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %%
stl = STL(l_san_df["FN024_Invest_Esgoto_Prestador"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %% [markdown]
# #### A série Invest_Esgoto_Prestador é a que eu consigo identificar mais padrões (parece ter algum padrão sazonal).

# %%
stl = STL(l_san_df["PIB"], seasonal=7, period = 25)
res = stl.fit()
fig = res.plot()

# %% [markdown]
# #### 6.1.2 Previsão com STL
#
# Veja [aqui](https://www.statsmodels.org/stable/examples/notebooks/generated/stl_decomposition.html).
#
# As séries diferenciadas parecem ser um ruído branco (quando olhamos o correlograma). Logo, não há necessidade de seguirmos com a previsão univariada.

# %%
# from IPython.display import Image
# Image("d_log_series.png")

# %% [markdown]
# ##### 6.2 Correlogram
#
# * As primeiras diferenças das séries são um ruído branco. A única exceção que cabe uma investigação é a série diferenciada do Invest_Esgoto_Prestador novamente, cujo primeiro lag da ACF e os dois primeiros da PACF são quase não significativos a 5%. Utilizando a metodologia de Box and Jenkins o melhor modelo usando os tradicionais critérios de informação é um MA(2). Cabe ressaltar que a amostra não é grande o suficiente para encontrarmos uma regularidade que permita utilizar com confiança a metodologia. <br><br>
#
# * Com a primeira diferença dos logs (série dos retornos) todas parecem um ruído branco.

# %%
# first diff

first_diff = san_df["FN024_Invest_Esgoto_Prestador"] - san_df["FN024_Invest_Esgoto_Prestador"].shift(1)
first_diff = first_diff.dropna(inplace = False)

# %%
# https://www.statsmodels.org/devel/examples/notebooks/generated/tsa_arma_0.html
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from scipy import stats
from statsmodels.graphics.api import qqplot

# %%
first_diff.plot(figsize=(12,8))

# %% [markdown]
# * The ACF plot shows the correlation of the time series with its own lags. Each vertical line (on the autocorrelation plot) represents the correlation between the series and its lag starting from lag 0. The blue shaded region in the plot is the significance level. Those lags that lie above the blue line are the significant lags.

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(first_diff.values.squeeze(), lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(first_diff, lags=10, ax=ax2)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
arma_mod21 = ARIMA(first_diff, order=(2, 0, 1)).fit()
print(arma_mod21.params)
# print(arma_mod21.aic, arma_mod21.bic, arma_mod21.hqic)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# const     2.556858e+06
# ar.L1     1.347065e+00
# ar.L2    -6.134643e-01
# ma.L1    -9.287789e-01
# sigma2    6.521374e+14
# dtype: float64

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)
ax = arma_mod21.resid.plot(ax=ax)

# %%
resid = arma_mod21.resid

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid.values.squeeze(), lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid, lags=10, ax=ax2)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
r, q, p = sm.tsa.acf(resid.values.squeeze(), fft=True, qstat=True)
data = np.c_[np.arange(1, 14), r[1:], q, p]

# %%
table = pd.DataFrame(data, columns=["lag", "AC", "Q", "Prob(>Q)"])
print(table.set_index("lag"))
# Out:
#             AC         Q  Prob(>Q)
# lag
# 1.0   0.108745  0.332591  0.564137
# 2.0  -0.071651  0.483258  0.785347
# 3.0  -0.336278  3.952850  0.266601
# 4.0   0.155825  4.733327  0.315770
# 5.0   0.086960  4.988547  0.417279
# 6.0  -0.093828  5.301309  0.505789
# 7.0  -0.228210  7.254307  0.402891
# 8.0  -0.072591  7.463534  0.487543
# 9.0  -0.072992  7.688305  0.565837
# 10.0 -0.036104  7.746963  0.653538
# 11.0  0.036716  7.811958  0.730043
# 12.0 -0.013931  7.822034  0.798879
# 13.0 -0.066412  8.070127  0.839002

# %% [markdown]
# * This indicates a proper fit.

# %% [markdown]
# ### 6.3 Dickey-Fuller tests

# %%
# Dickey-Fuller
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries, window = 12, cutoff = 0.01):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window).mean()
    rolstd = timeseries.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC', maxlag = 5 )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(dfoutput)

# %%
test_stationarity(first_diff, window=8)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0148. The series is likely non-stationary.
# Test Statistic                 -3.302166
# p-value                         0.014782
# #Lags Used                      1.000000
# Number of Observations Used    23.000000
# Critical Value (1%)            -3.752928
# Critical Value (5%)            -2.998500
# Critical Value (10%)           -2.638967
# dtype: float64

# %% [markdown]
# * No Gretl eu usei a opção sem constante para fazer o teste (de acordo com o gráfico da série me parece mais apropriado). O teste ADF acima utiliza a opção com constante. Descobri como fazer abaixo usando a função adfuller from statsmodels.
#     - Sem constante o p-valor assintótico é de 0.0007927 (feito no Gretl), isto é, rejeitamos a nula de que a série não é estacionária.<br><br>
#
# * Basicamente, todas estas séries são I(1), embora a confiança em uma afirmação como essa seja limitada pelo tamanho da amostra (alguns termos dificilmente desaparecem na parte matemática destes modelos com um T deste tamanho - é necessário que desapareçam para garantirmos a estacionariedade).

# %%
#https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html
df = sm.tsa.stattools.adfuller(first_diff, maxlag=8, regression='nc', autolag='AIC', regresults=True)

#dickey-fuller stat
print('O valor da estatística de teste de Dickey-Fuller é {:.4f}.'.format(df[0]))

#p-value
print('O valor do p-value associado a estatística de teste de Dickey-Fuller é {:.4f}.'.format(df[1]))
# Out:
# O valor da estatística de teste de Dickey-Fuller é -3.3495.
# O valor do p-value associado a estatística de teste de Dickey-Fuller é 0.0008.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:824: FutureWarning: trend 'nc' has been renamed to 'n' after 0.14 is released. Use 'n' now to avoid this warning.
#   FutureWarning,

# %%
df_kpss = sm.tsa.stattools.kpss(first_diff, regression='c')

#KPSS stat
print('O valor da estatística de teste de KPSS é {}.'.format(round(df_kpss[0],4)))
#p-value
print('O valor do p-value associado a estatística de teste de KPSS é {}.'.format(round(df_kpss[1],4)))
# Out:
# O valor da estatística de teste de KPSS é 0.0752.
# O valor do p-value associado a estatística de teste de KPSS é 0.1.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:2023: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %% [markdown]
# ### A nula do teste KPSS é estacionariedade. Para o ADF a nula é que a série contém uma raiz unitária.

# %% [markdown]
# ##### 6.3 Cross-Correlogram
#
# * As variáveis parecem ser todas coincidentes (fiz os gráficos no Gretl).

# %%
#calculate cross correlation
cc = sm.tsa.stattools.ccf(san_df['FN023_Invest_Agua_Prestador'], san_df['FN024_Invest_Esgoto_Prestador'], adjusted=False)

# %%
sm.tsa.stattools.ccf(san_df['FN023_Invest_Agua_Prestador'], san_df['FN024_Invest_Esgoto_Prestador'], adjusted=False)
# Out:
# array([ 0.88034436,  0.72989201,  0.52084315,  0.4044769 ,  0.30935981,
#         0.22802863,  0.17644576,  0.15369638,  0.1244343 ,  0.02918996,
#        -0.08113583, -0.18029268, -0.25671656, -0.29986678, -0.31633272,
#        -0.29345173, -0.26357488, -0.18795287, -0.13741602, -0.11968006,
#        -0.12562822, -0.11015614, -0.09201497, -0.06285101, -0.04990466,
#        -0.02759646])

# %%
#Interpretation
print('The cross correlation at lag 0 é {}.'.format(round(cc[0],4)))
#p-value
print('The cross correlation at lag 1 é {}.'.format(round(cc[1],4)))
# Out:
# The cross correlation at lag 0 é 0.8803.
# The cross correlation at lag 1 é 0.7299.

# %% [markdown]
# * Goal is to explain xxxx by independent variables of time-panel Dataframe df

# %% [markdown]
# # Sugestão de próximos passos?
